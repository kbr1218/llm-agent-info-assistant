# %% [markdown]
# ### LangGraph 시각화용
# > 그래프 구조을 확인하기 위한 그래프 시각화 파일

# %%
from langchain_teddynote.graphs import visualize_graph
from app.agent.graph import agent_excutor

visualize_graph(agent_excutor)
